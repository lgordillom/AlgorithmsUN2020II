# %% [markdown]
# # Lab 7
#
# Laura Ximena Gordillo Maldonado

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #####$z^3-2z+2$

# %%
def f2(z):
    return z ** 3 - 2*z +2
def df2(z):
    return 3* (z**2)- 2

# %%
def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-3 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    r1 = -1.76929235423863
    r2 = complex(0.88465, 0.58974)
    r3 = complex(0.88465, -0.58974)

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df2(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f2(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
               # print(z, " ", r1, " ", r2, " ", r3, " ", r4, " ")
                if abs(z-r1)<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                elif abs(z-r3)<=eps:
                    # color blue
                    pixels[height-y-1,x] = (0, 0, 255 - count*multcol)
                else:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

def display1(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal $f(z)= z^3-2z+2$')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %% [markdown]
# ###### Plot of $f(z)= z^3-2z+2$ for the reals $f(x) = x^3-2x+2$

# %%
x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,f2(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=$x^3-2x+2$')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# ###### Zoom out

# %%
display1(zoom=1)
display1(zoom=2)
display1(zoom=3)
display1(zoom=4)
display1(zoom=5)
# Out:
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ###### Zoom in

# %%
display1(zoom=1)
display1(zoom=1/2)
display1(zoom=1/3)
display1(zoom=1/4)
display1(zoom=1/5)
# Out:
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )

# %% [markdown]
# ###### Newton iterates form $z=10.0 + 0.0j$

# %%
z=10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df2(z)
  z = z - f2(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=10.0 + 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###### Newton iterates form $z=10.0 + 10.0j$

# %%
z=10.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df2(z)
  z = z - f2(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=10.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###### Newton iterates form $z=0.0 + 10.0j$

# %%
z=0.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df2(z)
  z = z - f2(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=0.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###### Newton iterates form $z=-10.0 - 10.0j$

# %%
z=-10.0 -10.0j
r=[]
i=[]
for k in range(50):
  dz = df2(z)
  z = z - f2(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=-10.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###### Newton iterates form $z=0.0 - 0.0j$

# %%
z=-0.0 -0.0j
r=[]
i=[]
for k in range(50):
  dz = df2(z)
  z = z - f2(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=-0.0 - 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %%
z=0.0 -10.0j
r=[]
i=[]
for k in range(50):
  dz = df2(z)
  z = z - f2(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=0.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###### **Analisis**
#
#
# > Los puntos convergen a las 3 raices distintas y se observan regiones oscuras donde los puntos divergen.

# %% [markdown]
# #####$z^8+15z^4-16$

# %%
def f1(z):
    return z ** 8 + 15* (z**4) - 16 
def df1(z):
    return 8*(z**7)+ 60*(z**3)

# %%
def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-5 # step size for numerical derivative
    eps = 1e-3# max error allowed

    # Bounding roots
    r2 = 1
    r1 = -1
    r7 = complex(0, -1)
    r8 = complex(0, 1)
    a=np.sqrt(2)
    r3 = complex(a, a)
    r4 = complex(-a, a)
    r5 = complex(a -a)
    r6 = complex(-a, -a)
    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df1(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f1(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext
                # Pixels colored using the roots
               # print(z, " ", r1, " ", r2, " ", r3, " ", r4, " ")
                if abs(z-r1)<=eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-r2)<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                elif abs(z-r3)<=eps:
                    # color blue
                    pixels[height-y-1,x] = (0, 0, 255 - count*multcol)
                elif abs(z-r4)<=eps:
                    # color yellow
                    pixels[height-y-1,x] = (255 - count*multcol, 255 - count*multcol, 0)
                elif abs(z-r5)<=eps:
                    # color cyan
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 255 - count*multcol)
                elif abs(z-r6)<=eps:
                    # color pink
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 255 - count*multcol)
                else:   
                   pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

def display3(z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal $f(x)=x^8+15x^4-16$')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %% [markdown]
# ###### Plot of $f(z)= z^8+15z^4-16$ for the reals $f(x) = x^8+15x^4-16$

# %%
x = np.linspace(-2.0,2.0,100)
fig, ax = plt.subplots()
ax.plot(x,f1(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.set_ylim([-17,20])
ax.grid(True, which='both')
plt.title('f(x)=$x^8+15x^4-16$')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# ###### Zoom out

# %%
display3(zoom=1)
display3(zoom=2)
display3(zoom=3)

display3(zoom=4)
display3(zoom=5)
# Out:
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.0 , -1.0 ) to ( 1.0 , 1.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.5 , -1.5 ) to ( 1.5 , 1.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.0 , -2.0 ) to ( 2.0 , 2.0 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ###### Zoom in

# %%
display3(zoom=1)
display3(zoom=1/2)
display3(zoom=1/3)
display3(zoom=1/4)
display3(zoom=1/5)
# Out:
# Z region from ( -0.5 , -0.5 ) to ( 0.5 , 0.5 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.25 , -0.25 ) to ( 0.25 , 0.25 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.16666666666666666 , -0.16666666666666666 ) to ( 0.16666666666666666 , 0.16666666666666666 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.125 , -0.125 ) to ( 0.125 , 0.125 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -0.1 , -0.1 ) to ( 0.1 , 0.1 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ###### Newton iterates form $z=10.0 + 0.0j$

# %%
z=10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df1(z)
  z = z - f1(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=10.0 + 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###### Newton iterates form $z=10.0 + 10.0j$

# %%
z=10.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df1(z)
  z = z - f1(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=10.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###### Newton iterates form $z=0.0 + 10.0j$

# %%
z=0.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df1(z)
  z = z - f1(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=0.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###### Newton iterates form $z=-10.0 - 10.0j$

# %%
z=-10.0 -10.0j
r=[]
i=[]
for k in range(50):
  dz = df1(z)
  z = z - f1(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=-10.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###### Newton iterates form $z=0.0 - 0.0j$

# %%
z=0.0 -0.0j
r=[]
i=[]
for k in range(50):
  dz = df1(z)
  z = z - f1(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=0.0 - 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-37-299c949c5cc7> in <module>()
#       4 for k in range(50):
#       5   dz = df1(z)
# ----> 6   z = z - f1(z) / dz # Newton iteration
#       7   r.append(np.real(z))
#       8   i.append(np.imag(z))
#
# ZeroDivisionError: complex division by zero

# %% [markdown]
# ###### Newton iterates form $z=0.0 - 10.0j$

# %%
z=0.0 -10.0j
r=[]
i=[]
for k in range(50):
  dz = df1(z)
  z = z - f1(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=0.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###### **Analisis**
#
#
# > Se puede observar como los puntos convergen a las distintas 8 raices, casi no se aprecian regiones en las que divergen.

# %% [markdown]
# #####$sin(z)$

# %%
def f3(z):
    return np.sin(z)
def df3(z):
    return np.cos(z)

# %%
def newton_set1(z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7# step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
    roots = np.array([0, np.pi, np.pi*2, np.pi*3])
    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = 5

    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df3(z)
                    if dz == 0:
                        break

                    count += 1
                    if count > 255:
                        break
                   
                    znext = z - f3(z) / dz # Newton iteration

                    if abs(znext - z) < eps: # stop when close enough to any root
                        break
                    
                    z = znext

                # Pixels colored using the roots
               # print(z, " ", r1, " ", r2, " ", r3, " ", r4, " ")
                if abs(z-roots[0])<eps:
                    # color red
                    pixels[height-y-1,x] = (255 - count*multcol, 0, 0)
                elif abs(z-roots[1])<=eps:
                    # color green
                    pixels[height-y-1,x] = (0, 255 - count*multcol, 0)
                elif abs(z-roots[2])<=eps:
                    # color blue
                    pixels[height-y-1,x] = (0, 0, 255 - count*multcol)
                elif abs(z-roots[3])<=eps:
                    # color yellow
                    pixels[height-y-1,x] = (255 - count*multcol, 255 - count*multcol, 0)
                else:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

def display2(z_c_r=np.pi/2, z_c_i=np.pi/2, zh = np.pi, zw=np.pi, width=500, height=500, zoom=1,  niter=256):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter)
    plt.title('Newton Fractal $sin(z)$')
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %% [markdown]
# ###### Plot of $f(z)= sin(z)$ for the reals $f(x) = sin(x)$

# %%
x = np.linspace(-3.5,3.5,100)
fig, ax = plt.subplots()
ax.plot(x,f3(x))
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=$sin(x)$')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# ###### Zoom out

# %%
display2(zoom=1)
display2(zoom=2)
display2(zoom=3)
# Out:
# Z region from ( 0.0 , 0.0 ) to ( 3.141592653589793 , 3.141592653589793 )
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in cos
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in sin
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: RuntimeWarning: invalid value encountered in cdouble_scalars
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -1.5707963267948966 , -1.5707963267948966 ) to ( 4.71238898038469 , 4.71238898038469 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( -3.141592653589793 , -3.141592653589793 ) to ( 6.283185307179586 , 6.283185307179586 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ###### Zoom in

# %%
display2(zoom=1)
display2(zoom=1/2)
display2(zoom=1/3)
# Out:
# Z region from ( 0.0 , 0.0 ) to ( 3.141592653589793 , 3.141592653589793 )
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in cos
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in sin
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: RuntimeWarning: invalid value encountered in cdouble_scalars
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( 0.7853981633974483 , 0.7853981633974483 ) to ( 2.356194490192345 , 2.356194490192345 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Z region from ( 1.0471975511965979 , 1.0471975511965979 ) to ( 2.0943951023931953 , 2.0943951023931953 )
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ###### Newton iterates form $z=10.0 + 0.0j$

# %%
z=10.0 + 0.0j
r=[]
i=[]
for k in range(50):
  dz = df3(z)
  z = z - f3(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=10.0 + 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###### Newton iterates form $z=10.0 + 10.0j$

# %%
z=10.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df3(z)
  z = z - f3(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=10.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###### Newton iterates form $z=0.0 + 10.0j$

# %%
z=0.0 + 10.0j
r=[]
i=[]
for k in range(50):
  dz = df3(z)
  z = z - f3(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=0.0 + 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###### Newton iterates form $z=-10.0 - 10.0j$

# %%
z=-10.0 -10.0j
r=[]
i=[]
for k in range(50):
  dz = df3(z)
  z = z - f3(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=-10.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###### Newton iterates form $z=-10.0 - 0.0j$

# %%
z=-10.0 -0.0j
r=[]
i=[]
for k in range(50):
  dz = df3(z)
  z = z - f3(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=-10.0 - 0.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###### Newton iterates form $z=0.0 - 10.0j$

# %%
z=0.0 -10.0j
r=[]
i=[]
for k in range(50):
  dz = df3(z)
  z = z - f3(z) / dz # Newton iteration
  r.append(np.real(z))
  i.append(np.imag(z))
plt.title('Newton iterates form $z=0.0 - 10.0j$')
plt.plot(r)
plt.ylabel('Real part')
plt.show()
plt.plot(i)
plt.ylabel('Imaginary part')
plt.show()

# %% [markdown]
# ###### **Analisis**
#
#
# > Este fractal se caracteriza por una lineas verticales generadas cada $\pi/2$, acompañadas de unas regiones elipticas donde los puntos convergen en las raices $\pi*n$
